# %%
import pandas as pd
from surprise import Dataset, Reader, SVD

# %%
def load_data():
    data = Dataset.load_builtin('ml-100k')
    raw_ratings = data.raw_ratings
    df = pd.DataFrame(raw_ratings, columns=['user_id', 'movie_id', 'rating', 'timestamp'])
    return df

df = load_data()
df
# Out:
#       user_id movie_id  rating  timestamp
# 0         196      242     3.0  881250949
# 1         186      302     3.0  891717742
# 2          22      377     1.0  878887116
# 3         244       51     2.0  880606923
# 4         166      346     1.0  886397596
# ...       ...      ...     ...        ...
# 99995     880      476     3.0  880175444
# 99996     716      204     5.0  879795543
# 99997     276     1090     1.0  874795795
# 99998      13      225     2.0  882399156
# 99999      12      203     3.0  879959583
#
# [100000 rows x 4 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    100000 non-null  object
#  1   movie_id   100000 non-null  object
#  2   rating     100000 non-null  float64
#  3   timestamp  100000 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 3.1+ MB

# %%
df["movie_id"] = df["movie_id"].astype(int)
df["user_id"] = df["user_id"].astype(int)

# %%
movie_titles = pd.read_csv('movies.csv', delimiter=',', header=0, encoding='latin-1')
movie_titles = movie_titles[pd.to_numeric(movie_titles['movieId'], errors='coerce').notnull()]
movie_titles["movieId"] = movie_titles["movieId"].astype("int32")
movie_titles = movie_titles[["movieId", "title"]]
movie_titles
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
# [62423 rows x 2 columns]

# %%
links = pd.read_csv('links.csv')
links['movieId'] = links['movieId'].astype(int)
links
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 62418   209157  6671244  499546.0
# 62419   209159   297986   63407.0
# 62420   209163  6755366  553036.0
# 62421   209169   249603  162892.0
# 62422   209171    55323   79513.0
#
# [62423 rows x 3 columns]

# %%
links.dropna(inplace=True)

# %%
links.tmdbId = links.tmdbId.astype(int)

# %%
links
# Out:
#        movieId   imdbId  tmdbId
# 0            1   114709     862
# 1            2   113497    8844
# 2            3   113228   15602
# 3            4   114885   31357
# 4            5   113041   11862
# ...        ...      ...     ...
# 62418   209157  6671244  499546
# 62419   209159   297986   63407
# 62420   209163  6755366  553036
# 62421   209169   249603  162892
# 62422   209171    55323   79513
#
# [62316 rows x 3 columns]

# %%
df = pd.merge(df, movie_titles, left_on='movie_id', right_on='movieId')
df
# Out:
#        user_id  movie_id  rating  timestamp  movieId  \
# 0          196       242     3.0  881250949      242
# 1          186       302     3.0  891717742      302
# 2           22       377     1.0  878887116      377
# 3          244        51     2.0  880606923       51
# 4          166       346     1.0  886397596      346
# ...        ...       ...     ...        ...      ...
# 98494      880       476     3.0  880175444      476
# 98495      716       204     5.0  879795543      204
# 98496      276      1090     1.0  874795795     1090
# 98497       13       225     2.0  882399156      225
# 98498       12       203     3.0  879959583      203
#
#                                                    title
# 0                          Farinelli: il castrato (1994)
# 1                 Queen Margot (Reine Margot, La) (1994)
# 2                                           Speed (1994)
# 3                                  Guardian Angel (1994)
# 4                                        Backbeat (1993)
# ...                                                  ...
# 98494                                Inkwell, The (1994)
# 98495               Under Siege 2: Dark Territory (1995)
# 98496                                     Platoon (1986)
# 98497                                  Disclosure (1994)
# 98498  To Wong Foo, Thanks for Everything! Julie Newm...
#
# [98499 rows x 6 columns]

# %%
df = df[["user_id", "movieId", "rating", "title"]]
df
# Out:
#        user_id  movieId  rating  \
# 0          196      242     3.0
# 1          186      302     3.0
# 2           22      377     1.0
# 3          244       51     2.0
# 4          166      346     1.0
# ...        ...      ...     ...
# 98494      880      476     3.0
# 98495      716      204     5.0
# 98496      276     1090     1.0
# 98497       13      225     2.0
# 98498       12      203     3.0
#
#                                                    title
# 0                          Farinelli: il castrato (1994)
# 1                 Queen Margot (Reine Margot, La) (1994)
# 2                                           Speed (1994)
# 3                                  Guardian Angel (1994)
# 4                                        Backbeat (1993)
# ...                                                  ...
# 98494                                Inkwell, The (1994)
# 98495               Under Siege 2: Dark Territory (1995)
# 98496                                     Platoon (1986)
# 98497                                  Disclosure (1994)
# 98498  To Wong Foo, Thanks for Everything! Julie Newm...
#
# [98499 rows x 4 columns]

# %%
df = pd.merge(df, links, on='movieId',how="inner")
df = df[["user_id", "movieId", "rating", "title", "tmdbId"]]

# %%
df
# Out:
#        user_id  movieId  rating  \
# 0          196      242     3.0
# 1          186      302     3.0
# 2           22      377     1.0
# 3          244       51     2.0
# 4          166      346     1.0
# ...        ...      ...     ...
# 98258      880      476     3.0
# 98259      716      204     5.0
# 98260      276     1090     1.0
# 98261       13      225     2.0
# 98262       12      203     3.0
#
#                                                    title  tmdbId
# 0                          Farinelli: il castrato (1994)   10954
# 1                 Queen Margot (Reine Margot, La) (1994)   10452
# 2                                           Speed (1994)    1637
# 3                                  Guardian Angel (1994)  117164
# 4                                        Backbeat (1993)   12635
# ...                                                  ...     ...
# 98258                                Inkwell, The (1994)   59930
# 98259               Under Siege 2: Dark Territory (1995)    3512
# 98260                                     Platoon (1986)     792
# 98261                                  Disclosure (1994)    8984
# 98262  To Wong Foo, Thanks for Everything! Julie Newm...    9090
#
# [98263 rows x 5 columns]

# %%
#save the data to a csv file
df.to_csv("ratings.csv", index=False)

# %%
d = pd.read_csv("ratings.csv")
d
# Out:
#        user_id  movieId  rating  \
# 0          196      242     3.0
# 1          186      302     3.0
# 2           22      377     1.0
# 3          244       51     2.0
# 4          166      346     1.0
# ...        ...      ...     ...
# 98258      880      476     3.0
# 98259      716      204     5.0
# 98260      276     1090     1.0
# 98261       13      225     2.0
# 98262       12      203     3.0
#
#                                                    title  tmdbId
# 0                          Farinelli: il castrato (1994)   10954
# 1                 Queen Margot (Reine Margot, La) (1994)   10452
# 2                                           Speed (1994)    1637
# 3                                  Guardian Angel (1994)  117164
# 4                                        Backbeat (1993)   12635
# ...                                                  ...     ...
# 98258                                Inkwell, The (1994)   59930
# 98259               Under Siege 2: Dark Territory (1995)    3512
# 98260                                     Platoon (1986)     792
# 98261                                  Disclosure (1994)    8984
# 98262  To Wong Foo, Thanks for Everything! Julie Newm...    9090
#
# [98263 rows x 5 columns]

# %% [markdown]
# ________________________

# %%
import pandas as pd
d = pd.read_csv("ratings.csv")
d
# Out:
#        user_id  movieId  rating  \
# 0          196      242     3.0
# 1          186      302     3.0
# 2           22      377     1.0
# 3          244       51     2.0
# 4          166      346     1.0
# ...        ...      ...     ...
# 98258      880      476     3.0
# 98259      716      204     5.0
# 98260      276     1090     1.0
# 98261       13      225     2.0
# 98262       12      203     3.0
#
#                                                    title  tmdbId
# 0                          Farinelli: il castrato (1994)   10954
# 1                 Queen Margot (Reine Margot, La) (1994)   10452
# 2                                           Speed (1994)    1637
# 3                                  Guardian Angel (1994)  117164
# 4                                        Backbeat (1993)   12635
# ...                                                  ...     ...
# 98258                                Inkwell, The (1994)   59930
# 98259               Under Siege 2: Dark Territory (1995)    3512
# 98260                                     Platoon (1986)     792
# 98261                                  Disclosure (1994)    8984
# 98262  To Wong Foo, Thanks for Everything! Julie Newm...    9090
#
# [98263 rows x 5 columns]

# %%
movies = pd.read_csv("movies.csv")
movies
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...                                            ...
# 62418                                        Drama
# 62419                                  Documentary
# 62420                                 Comedy|Drama
# 62421                           (no genres listed)
# 62422                       Action|Adventure|Drama
#
# [62423 rows x 3 columns]

# %%
ratings_v2 = pd.merge(d, movies, on="movieId")
ratings_v2
# Out:
#        user_id  movieId  rating  \
# 0          196      242     3.0
# 1          186      302     3.0
# 2           22      377     1.0
# 3          244       51     2.0
# 4          166      346     1.0
# ...        ...      ...     ...
# 98258      880      476     3.0
# 98259      716      204     5.0
# 98260      276     1090     1.0
# 98261       13      225     2.0
# 98262       12      203     3.0
#
#                                                  title_x  tmdbId  \
# 0                          Farinelli: il castrato (1994)   10954
# 1                 Queen Margot (Reine Margot, La) (1994)   10452
# 2                                           Speed (1994)    1637
# 3                                  Guardian Angel (1994)  117164
# 4                                        Backbeat (1993)   12635
# ...                                                  ...     ...
# 98258                                Inkwell, The (1994)   59930
# 98259               Under Siege 2: Dark Territory (1995)    3512
# 98260                                     Platoon (1986)     792
# 98261                                  Disclosure (1994)    8984
# 98262  To Wong Foo, Thanks for Everything! Julie Newm...    9090
#
#                                                  title_y  \
# 0                          Farinelli: il castrato (1994)
# 1                 Queen Margot (Reine Margot, La) (1994)
# 2                                           Speed (1994)
# 3                                  Guardian Angel (1994)
# 4                                        Backbeat (1993)
# ...                                                  ...
# 98258                                Inkwell, The (1994)
# 98259               Under Siege 2: Dark Territory (1995)
# 98260                                     Platoon (1986)
# 98261                                  Disclosure (1994)
# 98262  To Wong Foo, Thanks for Everything! Julie Newm...
#
#                         genres
# 0                Drama|Musical
# 1                Drama|Romance
# 2      Action|Romance|Thriller
# 3        Action|Drama|Thriller
# 4                Drama|Musical
# ...                        ...
# 98258             Comedy|Drama
# 98259                   Action
# 98260                Drama|War
# 98261           Drama|Thriller
# 98262                   Comedy
#
# [98263 rows x 7 columns]

# %%
ratings_v2.drop(columns=["title_y"], inplace=True)
ratings_v2.rename(columns={"title_x":"title"}, inplace=True)
ratings_v2
# Out:
#        user_id  movieId  rating  \
# 0          196      242     3.0
# 1          186      302     3.0
# 2           22      377     1.0
# 3          244       51     2.0
# 4          166      346     1.0
# ...        ...      ...     ...
# 98258      880      476     3.0
# 98259      716      204     5.0
# 98260      276     1090     1.0
# 98261       13      225     2.0
# 98262       12      203     3.0
#
#                                                    title  tmdbId  \
# 0                          Farinelli: il castrato (1994)   10954
# 1                 Queen Margot (Reine Margot, La) (1994)   10452
# 2                                           Speed (1994)    1637
# 3                                  Guardian Angel (1994)  117164
# 4                                        Backbeat (1993)   12635
# ...                                                  ...     ...
# 98258                                Inkwell, The (1994)   59930
# 98259               Under Siege 2: Dark Territory (1995)    3512
# 98260                                     Platoon (1986)     792
# 98261                                  Disclosure (1994)    8984
# 98262  To Wong Foo, Thanks for Everything! Julie Newm...    9090
#
#                         genres
# 0                Drama|Musical
# 1                Drama|Romance
# 2      Action|Romance|Thriller
# 3        Action|Drama|Thriller
# 4                Drama|Musical
# ...                        ...
# 98258             Comedy|Drama
# 98259                   Action
# 98260                Drama|War
# 98261           Drama|Thriller
# 98262                   Comedy
#
# [98263 rows x 6 columns]

# %% [markdown]
# Content based data preparation

# %%
ratings_v2.shape
# Out:
# (98263, 6)
